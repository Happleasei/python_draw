# %% [markdown]
# # 线图

# %% [markdown]
# ##  y = kx + b

# %%
from pylab import *
# mpl.rcParams['font.sans-serif'] = ['SimHei']  # 添加这条可以让图形显示中文

x = [1, 2, 3, 4, 5]
# 此处可调kx + b
k = 3
b = 1
y = [k*_+b for _ in x] 

# plot中参数的含义分别是横轴值，纵轴值，线的形状，颜色，透明度,线的宽度和标签
plt.plot(x, y, 'o-', color='#4169E1', alpha=0.8, linewidth=1, label='label')

# 显示标签
plt.legend(loc="upper right")
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# ## y = x**3

# %%
from pylab import *
# mpl.rcParams['font.sans-serif'] = ['SimHei']  # 添加这条可以让图形显示中文

x = [1, 2, 3, 4, 5]
# 此处可调kx + b
y = [_**3 for _ in x]

# plot中参数的含义分别是横轴值，纵轴值，线的形状，颜色，透明度,线的宽度和标签
plt.plot(x, y, 'o-', color='#4169E1', alpha=0.8, linewidth=1, label='label')

# 显示标签
plt.legend(loc="upper right")
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# ## y = 1/x**3

# %%
from pylab import *
# mpl.rcParams['font.sans-serif'] = ['SimHei']  # 添加这条可以让图形显示中文

x = [1, 2, 3, 4, 5]
# 此处可调kx + b
y = [_**(-3) for _ in x]

# plot中参数的含义分别是横轴值，纵轴值，线的形状，颜色，透明度,线的宽度和标签
plt.plot(x, y, 'o-', color='#4169E1', alpha=0.8, linewidth=1, label='label')

# 显示标签
plt.legend(loc="upper right")
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# # 其余函数根据y和x公式设计

# %% [markdown]
# ## 圆

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2 * np.pi, 200)

x = np.cos(theta)
y = np.sin(theta)

fig, ax = plt.subplots(figsize=(4, 4))
ax.plot(x, y, color="darkred", linewidth=2)
ax.xaxis.set_major_locator(plt.NullLocator()) # 删除x轴刻度，如需显示x轴刻度注释该行代码即可。
ax.yaxis.set_major_locator(plt.NullLocator()) # 删除y轴刻度，如需显示y轴刻度注释该行代码即可。
ax.axis("equal")
# Out:
# (-1.09986915899354, 1.0999937694758828, -1.099965731583572, 1.099965731583572)

# %% [markdown]
# ## 椭圆

# %%
from matplotlib.patches import Ellipse
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
ell1 = Ellipse(xy = (0.0, 0.0), width = 4, height = 8, angle = 90.0, color="darkred", alpha=0.3)
ax.add_patch(ell1)
x, y = 0, 0   
ax.plot(x, y, 'ro')
plt.show()
